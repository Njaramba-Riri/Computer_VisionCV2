# %%
import cv2

img = cv2.imread("Images/Img2.jpeg", cv2.IMREAD_GRAYSCALE)

if img is None or img.size == 0:
    print("Error while trying to load the image")
else:
    cv2.imshow("image", img)
    
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.array([ [0,255,0,255],[255,0,255,0],[0,0,0,255],[255,0,255,0] ])
plt.imshow(x,cmap='gray')
plt.show();

# %%
2+6
# Out:
# 8

# %%
import cv2
import matplotlib.pyplot as plt

img=cv2.imread('Images/Img1.jpeg')

# %%
cv2.imshow('Image', img)

cv2.waitKey(0)
cv2.destroyALLWindows()

# %%
import cv2

img=cv2.imread('Images/Img1.jpeg')
array= np.array(img)

print(array)
# Out:
# [[[203 212 222]
#   [204 213 223]
#   [204 213 223]
#   ...
#   [192 214 239]
#   [191 213 238]
#   [191 213 238]]
#
#  [[200 209 219]
#   [200 209 219]
#   [201 210 220]
#   ...
#   [192 214 239]
#   [192 214 239]
#   [192 214 239]]
#
#  [[199 208 218]
#   [199 208 218]
#   [199 208 218]
#   ...
#   [193 215 240]
#   [193 215 240]
#   [193 215 240]]
#
#  ...
#
#  [[ 43  39  34]
#   [ 37  33  28]
#   [ 49  45  40]
#   ...
#   [ 27  23  22]
#   [ 28  24  23]
#   [ 22  18  17]]
#
#  [[ 37  33  28]
#   [ 30  26  21]
#   [ 55  51  46]
#   ...
#   [ 26  22  21]
#   [ 27  23  22]
#   [ 21  17  16]]
#
#  [[ 29  25  20]
#   [ 42  38  33]
#   [ 69  66  58]
#   ...
#   [ 24  20  19]
#   [ 27  23  22]
#   [ 23  19  18]]]

# %%
plt.imshow(array)
plt.show();
